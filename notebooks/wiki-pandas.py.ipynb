# %%
import pandas as pd
import os
import csv

# %%
# Set filename
db_filename = "wikidata" + os.path.sep + "wikidb_parsed.csv"

# Load the DataFrame
wiki_df = pd.read_csv(db_filename)

# %%
letterpath = 'letterdata'

letterpaths = [os.path.join(letterpath, f) for f in os.listdir(letterpath)]

dfs = []

# Get a list of DataFrames from CSV's
for path in letterpaths:
    try:
        dfs.append(pd.read_csv(path, index_col=None, header=None, encoding='utf-8'))
    except UnicodeDecodeError:
        dfs.append(pd.read_csv(path, index_col=None, header=None, encoding='windows-1252'))

# Concatenate all together
suomi_df = pd.concat(dfs, axis=0, ignore_index=True)

# %%
suomi_df.columns = ['title', 'taiv']

# %%
# Do an INNER JOIN between suomi sanakirjat and wiktionary words
df = pd.merge(suomi_df, wiki_df, how='inner', on=['title']).drop(['taiv', 'orig_index'],axis=1)

# Force lower case
df["title"] = df["title"].str.lower()

# Drop any duplicate words
df.drop_duplicates(subset=['title'], inplace=True)

# Drop words longer than 14 characters. Most are too difficult for games.
df = df[df['title'].map(len) < 14]

# Reset the index
df = df.reset_index(drop=True)

# %%
df[df['is_subs']].sample(30)
# Out:
#               title  is_verb  is_subs  is_adje  is_nume  is_name
# 10378     kissapeto    False     True    False    False    False
# 26957   symboliikka    False     True    False    False    False
# 3845     hallitsija    False     True    False    False    False
# 32629  viiniköynnös    False     True    False    False    False
# 23061      riiputus    False     True    False    False    False
# 17412    nujakointi    False     True    False    False    False
# 7602          jätti    False     True    False    False    False
# 9033    kauppahalli    False     True    False    False    False
# 34176       ärähdys    False     True    False    False    False
# 8181       kalmukki    False     True    False    False    False
# 25719   skalpeeraus    False     True    False    False    False
# 636            alho    False     True    False    False    False
# 18359        ostari    False     True    False    False    False
# 26180        spasmi    False     True    False    False    False
# 11811          kulu    False     True    False    False    False
# 32312       veskari    False     True    False    False    False
# 24590    sappirakko    False     True    False    False    False
# 16110        mulkku    False     True    False    False    False
# 10165  kippurahäntä    False     True    False    False    False
# 9583   kestomakkara    False     True    False    False    False
# 721      alkupääoma    False     True    False    False    False
# 8338     kannattaja    False     True    False    False    False
# 28769   tilinpäätös    False     True    False    False    False
# 27244    sähköposti    False     True    False    False    False
# 6981        jodlaus    False     True    False    False    False
# 7990         kakara    False     True    False    False    False
# 24569   sanomalehti    False     True    False    False    False
# 6827    jalkaraudat    False     True    False    False    False
# 5371     huopahattu    False     True    False    False    False
# 33334      väkevyys    False     True    False    False    False

# %%
df.tail()
# Out:
#                title  is_verb  is_subs  is_adje  is_nume  is_name
# 34343        öykkäri    False     True    False    False    False
# 34344  öykkärimäinen    False    False     True    False    False
# 34345     öykkäröidä     True    False    False    False    False
# 34346    öykkäröinti    False     True    False    False    False
# 34347        öylätti    False     True    False    False    False

# %%
# df.index.name = 'id'

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///corpus.db', echo=True)
conn = engine.connect()
# Out:
# 2020-09-05 16:32:22,620 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-09-05 16:32:22,621 INFO sqlalchemy.engine.base.Engine ()
# 2020-09-05 16:32:22,623 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-09-05 16:32:22,623 INFO sqlalchemy.engine.base.Engine ()

# %%
tablename = "words"

df.to_sql(tablename, conn, if_exists='replace', index_label='id')
# Out:
# 2020-09-05 16:32:23,086 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("words")
# 2020-09-05 16:32:23,087 INFO sqlalchemy.engine.base.Engine ()
# 2020-09-05 16:32:23,088 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("words")
# 2020-09-05 16:32:23,088 INFO sqlalchemy.engine.base.Engine ()
# 2020-09-05 16:32:23,089 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2020-09-05 16:32:23,090 INFO sqlalchemy.engine.base.Engine ()
# 2020-09-05 16:32:23,090 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("words")
# 2020-09-05 16:32:23,091 INFO sqlalchemy.engine.base.Engine ()
# 2020-09-05 16:32:23,094 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2020-09-05 16:32:23,095 INFO sqlalchemy.engine.base.Engine ('words',)
# 2020-09-05 16:32:23,096 INFO sqlalchemy.engine.base.Engine PRAGMA main.foreign_key_list("words")
# 2020-09-05 16:32:23,097 INFO sqlalchemy.engine.base.Engine ()
# 2020-09-05 16:32:23,098 INFO sqlalchemy.engine.base.Engine PRAGMA temp.foreign_key_list("words")
# 2020-09-05 16:32:23,098 INFO sqlalchemy.engine.base.Engine ()
# 2020-09-05 16:32:23,099 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2020-09-05 16:32:23,100 INFO sqlalchemy.engine.base.Engine ('words',)
# 2020-09-05 16:32:23,102 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("words")
# 2020-09-05 16:32:23,103 INFO sqlalchemy.engine.base.Engine ()
# 2020-09-05 16:32:23,104 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_info("ix_words_id")
# 2020-09-05 16:32:23,105 INFO sqlalchemy.engine.base.Engine ()
# 2020-09-05 16:32:23,105 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("words")
# 2020-09-05 16:32:23,106 INFO sqlalchemy.engine.base.Engine ()
# 2020-09-05 16:32:23,108 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_info("ix_words_id")
# 2020-09-05 16:32:23,108 INFO sqlalchemy.engine.base.Engine ()
# 2020-09-05 16:32:23,109 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2020-09-05 16:32:23,110 INFO sqlalchemy.engine.base.Engine ('words',)
# 2020-09-05 16:32:23,112 INFO sqlalchemy.engine.base.Engine
# DROP TABLE words
# 2020-09-05 16:32:23,113 INFO sqlalchemy.engine.base.Engine ()
# 2020-09-05 16:32:23,126 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-09-05 16:32:23,129 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE words (
# 	id BIGINT,
# 	title TEXT,
# 	is_verb BOOLEAN,
# 	is_subs BOOLEAN,
# 	is_adje BOOLEAN,
# 	is_nume BOOLEAN,
# 	is_name BOOLEAN,
# 	CHECK (is_verb IN (0, 1)),
# 	CHECK (is_subs IN (0, 1)),
# 	CHECK (is_adje IN (0, 1)),
# 	CHECK (is_nume IN (0, 1)),
# 	CHECK (is_name IN (0, 1))
# )
#
#
# 2020-09-05 16:32:23,130 INFO sqlalchemy.engine.base.Engine ()
# 2020-09-05 16:32:23,141 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-09-05 16:32:23,142 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_words_id ON words (id)
# 2020-09-05 16:32:23,143 INFO sqlalchemy.engine.base.Engine ()
# 2020-09-05 16:32:23,154 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-09-05 16:32:23,162 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-09-05 16:32:23,449 INFO sqlalchemy.engine.base.Engine INSERT INTO words (id, title, is_verb, is_subs, is_adje, is_nume, is_name) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2020-09-05 16:32:23,450 INFO sqlalchemy.engine.base.Engine ((0, 'aakkonen', 0, 1, 0, 0, 0), (1, 'aakkosellinen', 0, 0, 1, 0, 0), (2, 'aakkostaa', 1, 0, 0, 0, 0), (3, 'aakkosto', 0, 1, 0, 0, 0), (4, 'aakkostus', 0, 1, 0, 0, 0), (5, 'aalloittainen', 0, 0, 1, 0, 0), (6, 'aallokas', 0, 0, 1, 0, 0), (7, 'aallokko', 0, 1, 0, 0, 0)  ... displaying 10 of 34348 total bound parameter sets ...  (34346, 'öykkäröinti', 0, 1, 0, 0, 0), (34347, 'öylätti', 0, 1, 0, 0, 0))
# 2020-09-05 16:32:23,516 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
engine.execute("SELECT * FROM words").fetchall()
# Out:
# 2020-09-05 16:34:24,484 INFO sqlalchemy.engine.base.Engine SELECT * FROM words
# 2020-09-05 16:34:24,484 INFO sqlalchemy.engine.base.Engine ()
# [(0, 'aakkonen', 0, 1, 0, 0, 0),
#  (1, 'aakkosellinen', 0, 0, 1, 0, 0),
#  (2, 'aakkostaa', 1, 0, 0, 0, 0),
#  (3, 'aakkosto', 0, 1, 0, 0, 0),
#  (4, 'aakkostus', 0, 1, 0, 0, 0),
#  (5, 'aalloittainen', 0, 0, 1, 0, 0),
#  (6, 'aallokas', 0, 0, 1, 0, 0),
#  (7, 'aallokko', 0, 1, 0, 0, 0),
#  (8, 'aallonharja', 0, 1, 0, 0, 0),
#  (9, 'aallonmurtaja', 0, 1, 0, 0, 0),
#  (10, 'aallonpituus', 0, 1, 0, 0, 0),
#  (11, 'aallonpohja', 0, 1, 0, 0, 0),
#  (12, 'aallota', 1, 0, 0, 0, 0),
#  (13, 'aallotar', 0, 1, 0, 0, 0),
#  (14, 'aallotus', 0, 1, 0, 0, 0),
#  (15, 'aaloe', 0, 1, 0, 0, 0),
#  (16, 'aalto', 0, 1, 0, 0, 0),
#  (17, 'aaltoalue', 0, 1, 0, 0, 0),
#  (18, 'aaltoenergia', 0, 1, 0, 0, 0),
#  (19, 'aaltoilla', 1, 0, 0, 0, 0),
#  (20, 'aaltoilu', 0, 1, 0, 0, 0),
#  (21, 'aaltolevy', 0, 1, 0, 0, 0),
#  (22, 'aaltoliike', 0, 1, 0, 0, 0),
#  (23, 'aaltopahvi', 0, 1, 0, 0, 0),
#  (24, 'aaltopelti', 0, 1, 0, 0, 0),
#  (25, 'aaltopituus', 0, 1, 0, 0, 0),
#  (26, 'aaltosulje', 0, 1, 0, 0, 0),
#  (27, 'aaltosulku', 0, 1, 0, 0, 0),
#  (28, 'aaltoviiva', 0, 1, 0, 0, 0),
#  (29, 'aaltovoimala', 0, 1, 0, 0, 0),
#  (30, 'aamen', 0, 0, 0, 0, 0),
#  (31, 'aamiainen', 0, 1, 0, 0, 0),
#  (32, 'aamu', 0, 1, 0, 0, 0),
#  (33, 'aamu-unisuus', 0, 1, 0, 0, 0),
#  (34, 'aamuhartaus', 0, 1, 0, 0, 0),
#  (35, 'aamuhämärä', 0, 1, 0, 0, 0),
#  (36, 'aamuinen', 0, 0, 1, 0, 0),
#  (37, 'aamujuna', 0, 1, 0, 0, 0),
#  (38, 'aamukahvi', 0, 1, 0, 0, 0),
#  (39, 'aamukaste', 0, 1, 0, 0, 0),
#  (40, 'aamukylmä', 0, 1, 0, 0, 0),
#  (41, 'aamulehti', 0, 1, 0, 0, 0),
#  (42, 'aamullinen', 0, 0, 1, 0, 0),
#  (43, 'aamulypsy', 0, 1, 0, 0, 0),
#  (44, 'aamulämpö', 0, 1, 0, 0, 0),
#  (45, 'aamunkoitto', 0, 1, 0, 0, 0),
#  (46, 'aamunsarastus', 0, 1, 0, 0, 0),
#  (47, 'aamupala', 0, 1, 0, 0, 0),
#  (48, 'aamupesu', 0, 1, 0, 0, 0),
#  (49, 'aamupäivä', 0, 1, 0, 0, 0),
#  (50, 'aamurusko', 0, 1, 0, 0, 0),
#  (51, 'aamutakki', 0, 1, 0, 0, 0),
#  (52, 'aamutossu', 0, 1, 0, 0, 0),
#  (53, 'aamutähti', 0, 1, 0, 0, 0),
#  (54, 'aamuvarhainen', 0, 1, 0, 0, 0),
#  (55, 'aamuvirkku', 0, 1, 0, 0, 0),
#  (56, 'aamuvuoro', 0, 1, 0, 0, 0),
#  (57, 'aapa', 0, 1, 0, 0, 0),
#  (58, 'aapasuo', 0, 1, 0, 0, 0),
#  (59, 'aapinen', 0, 1, 0, 0, 0),
#  (60, 'aapiskirja', 0, 1, 0, 0, 0),
#  (61, 'aaprotti', 0, 1, 0, 0, 0),
#  (62, 'aari', 0, 1, 0, 0, 0),
#  (63, 'aaria', 0, 1, 0, 0, 0),
#  (64, 'aarnialue', 0, 1, 0, 0, 0),
#  (65, 'aarnihauta', 0, 1, 0, 0, 0),
#  (66, 'aarnikotka', 0, 1, 0, 0, 0),
#  (67, 'aarnio', 0, 1, 0, 0, 0),
#  (68, 'aarniometsä', 0, 1, 0, 0, 0),
#  (69, 'aarnituli', 0, 1, 0, 0, 0),
#  (70, 'aarnivalkea', 0, 1, 0, 0, 0),
#  (71, 'aaroninparta', 0, 1, 0, 0, 0),
#  (72, 'aarpora', 0, 1, 0, 0, 0),
#  (73, 'aarre', 0, 1, 0, 0, 0),
#  (74, 'aarreaitta', 0, 1, 0, 0, 0),
#  (75, 'aarrelöytö', 0, 1, 0, 0, 0),
#  (76, 'aarteenetsijä', 0, 1, 0, 0, 0),
#  (77, 'aasi', 0, 1, 0, 0, 0),
#  (78, 'aasialainen', 0, 1, 1, 0, 0),
#  (79, 'aasialaisuus', 0, 1, 0, 0, 0),
#  (80, 'aasimainen', 0, 0, 1, 0, 0),
#  (81, 'aasimaisuus', 0, 1, 0, 0, 0),
#  (82, 'aasinpotku', 0, 1, 0, 0, 0),
#  (83, 'aasinsilta', 0, 1, 0, 0, 0),
#  (84, 'aatami', 0, 1, 0, 0, 0),
#  (85, 'aataminomena', 0, 1, 0, 0, 0),
#  (86, 'aate', 0, 1, 0, 0, 0),
#  (87, 'aatehistoria', 0, 1, 0, 0, 0),
#  (88, 'aateli', 0, 1, 0, 0, 0),
#  (89, 'aatelinen', 0, 1, 1, 0, 0),
#  (90, 'aatelisarvo', 0, 1, 0, 0, 0),
#  (91, 'aatelissääty', 0, 1, 0, 0, 0),
#  (92, 'aatelisto', 0, 1, 0, 0, 0),
#  (93, 'aatelisuus', 0, 1, 0, 0, 0),
#  (94, 'aateliton', 0, 1, 1, 0, 0),
#  (95, 'aateloida', 1, 0, 0, 0, 0),
#  (96, 'aatelointi', 0, 1, 0, 0, 0),
#  (97, 'aateluus', 0, 1, 0, 0, 0),
#  (98, 'aatetoveri', 0, 1, 0, 0, 0),
#  (99, 'aatevirtaus', 0, 1, 0, 0, 0),
#  (100, 'aatos', 0, 1, 0, 0, 0),
#  (101, 'aatra', 0, 1, 0, 0, 0),
#  (102, 'aatteellinen', 0, 0, 1, 0, 0),
#  (103, 'aatteellisuus', 0, 1, 0, 0, 0),
#  (104, 'aatto', 0, 1, 0, 0, 0),
#  (105, 'aava', 0, 1, 1, 0, 0),
#  (106, 'aavameri', 0, 1, 0, 0, 0),
#  (107, 'aave', 0, 1, 0, 0, 0),
#  (108, 'aavejuna', 0, 1, 0, 0, 0),
#  (109, 'aavekipu', 0, 1, 0, 0, 0),
#  (110, 'aavelaiva', 0, 1, 0, 0, 0),
#  (111, 'aavemainen', 0, 0, 1, 0, 0),
#  (112, 'aavemaisuus', 0, 1, 0, 0, 0),
#  (113, 'aavikko', 0, 1, 0, 0, 0),
#  (114, 'aavikoitua', 1, 0, 0, 0, 0),
#  (115, 'aavistaa', 1, 0, 0, 0, 0),
#  (116, 'aavistamaton', 0, 0, 0, 0, 0),
#  (117, 'aavistella', 1, 0, 0, 0, 0),
#  (118, 'aavistus', 0, 1, 0, 0, 0),
#  (119, 'aavistuslähtö', 0, 1, 0, 0, 0),
#  (120, 'abatsi', 0, 1, 0, 0, 0),
#  (121, 'abbedissa', 0, 1, 0, 0, 0),
#  (122, 'abessiivi', 0, 1, 0, 0, 0),
#  (123, 'abi', 0, 1, 0, 0, 0),
#  (124, 'abiturientti', 0, 1, 0, 0, 0),
#  (125, 'ablatiivi', 0, 1, 0, 0, 0),
#  (126, 'abnormius', 0, 1, 0, 0, 0),
#  (127, 'abo', 0, 1, 0, 0, 0),
#  (128, 'abortoida', 1, 0, 0, 0, 0),
#  (129, 'abortointi', 0, 1, 0, 0, 0),
#  (130, 'abortti', 0, 1, 0, 0, 0),
#  (131, 'abrakadabra', 0, 1, 0, 0, 0),
#  (132, 'abskissa', 0, 1, 0, 0, 0),
#  (133, 'absolutismi', 0, 1, 0, 0, 0),
#  (134, 'absolutisti', 0, 1, 0, 0, 0),
#  (135, 'absoluutti', 0, 1, 0, 0, 0),
#  (136, 'absorboida', 1, 0, 0, 0, 0),
#  (137, 'absorbointi', 0, 1, 0, 0, 0),
#  (138, 'absorboitua', 1, 0, 0, 0, 0),
#  (139, 'abstrahoida', 1, 0, 0, 0, 0),
#  (140, 'abstrahointi', 0, 1, 0, 0, 0),
#  (141, 'abstrakti', 0, 1, 1, 0, 0),
#  (142, 'abstraktinen', 0, 0, 1, 0, 0),
#  (143, 'abstraktio', 0, 1, 0, 0, 0),
#  (144, 'abstraktisuus', 0, 1, 0, 0, 0),
#  (145, 'abstraktius', 0, 1, 0, 0, 0),
#  (146, 'absurdius', 0, 1, 0, 0, 0),
#  (147, 'adagio', 0, 1, 0, 0, 0),
#  (148, 'adaptaatio', 0, 1, 0, 0, 0),
#  (149, 'adaptointi', 0, 1, 0, 0, 0),
#  (150, 'adaptoitua', 1, 0, 0, 0, 0),
#  (151, 'addikti', 0, 1, 0, 0, 0),
#  (152, 'addiktio', 0, 1, 0, 0, 0),
#  (153, 'adekvaatti', 0, 0, 1, 0, 0),
#  (154, 'adekvaattius', 0, 1, 0, 0, 0),
#  (155, 'adenooma', 0, 1, 0, 0, 0),
#  (156, 'adessiivi', 0, 1, 0, 0, 0),
#  (157, 'adheesio', 0, 1, 0, 0, 0),
#  (158, 'adjektiivi', 0, 1, 0, 0, 0),
#  (159, 'adjektiivinen', 0, 0, 1, 0, 0),
#  (160, 'adjutantti', 0, 1, 0, 0, 0),
#  (161, 'adoptio', 0, 1, 0, 0, 0),
#  (162, 'adoptiolapsi', 0, 1, 0, 0, 0),
#  (163, 'adoptoida', 1, 0, 0, 0, 0),
#  (164, 'adoptointi', 0, 1, 0, 0, 0),
#  (165, 'adrenaliini', 0, 1, 0, 0, 0),
#  (166, 'adressi', 0, 1, 0, 0, 0),
#  (167, 'adsorboida', 1, 0, 0, 0, 0),
#  (168, 'adsorbointi', 0, 1, 0, 0, 0),
#  (169, 'adventismi', 0, 1, 0, 0, 0),
#  (170, 'adventisti', 0, 1, 0, 0, 0),
#  (171, 'adventti', 0, 1, 0, 0, 0),
#  (172, 'adverbi', 0, 1, 0, 0, 0),
#  (173, 'adverbiaali', 0, 1, 0, 0, 0),
#  (174, 'adverbisuus', 0, 1, 0, 0, 0),
#  (175, 'aerobic', 0, 1, 0, 0, 0),
#  (176, 'aerobikata', 1, 0, 0, 0, 0),
#  (177, 'aerobinen', 0, 0, 1, 0, 0),
#  (178, 'aerobiologia', 0, 1, 0, 0, 0),
#  (179, 'aerosoli', 0, 1, 0, 0, 0),
#  (180, 'afaatikko', 0, 1, 0, 0, 0),
#  (181, 'afaattinen', 0, 0, 1, 0, 0),
#  (182, 'afasia', 0, 1, 0, 0, 0),
#  (183, 'affekti', 0, 1, 0, 0, 0),
#  (184, 'affektinen', 0, 0, 1, 0, 0),
#  (185, 'affektisuus', 0, 1, 0, 0, 0),
#  (186, 'afgaani', 0, 1, 0, 0, 0),
#  (187, 'afrikaans', 0, 1, 0, 0, 0),
#  (188, 'afrikandi', 0, 1, 0, 0, 0),
#  (189, 'afrikkalainen', 0, 1, 1, 0, 0),
#  (190, 'afro', 0, 1, 0, 0, 0),
#  (191, 'afrokampaus', 0, 1, 0, 0, 0),
#  (192, 'afta', 0, 1, 0, 0, 0),
#  (193, 'afääri', 0, 1, 0, 0, 0),
#  (194, 'agaatti', 0, 1, 0, 0, 0),
#  (195, 'agaave', 0, 1, 0, 0, 0),
#  (196, 'agar', 0, 1, 0, 0, 0),
#  (197, 'agar-agar', 0, 1, 0, 0, 0),
#  (198, 'agentti', 0, 1, 0, 0, 0),
#  (199, 'agentuuri', 0, 1, 0, 0, 0),
#  (200, 'aggregaatti', 0, 1, 0, 0, 0),
#  (201, 'aggressio', 0, 1, 0, 0, 0),
#  (202, 'agitaattori', 0, 1, 0, 0, 0),
#  (203, 'agitoida', 1, 0, 0, 0, 0),
#  (204, 'agitointi', 0, 1, 0, 0, 0),
#  (205, 'agnostikko', 0, 1, 0, 0, 0),
#  (206, 'agnostinen', 0, 0, 1, 0, 0),
#  (207, 'agnostisismi', 0, 1, 0, 0, 0),
#  (208, 'agnostisuus', 0, 1, 0, 0, 0),
#  (209, 'agorafobia', 0, 1, 0, 0, 0),
#  (210, 'agraarinen', 0, 0, 1, 0, 0),
#  (211, 'agraaripuolue', 0, 1, 0, 0, 0),
#  (212, 'agraarisuus', 0, 1, 0, 0, 0),
#  (213, 'agraarivaltio', 0, 1, 0, 0, 0),
#  (214, 'agrologi', 0, 1, 0, 0, 0),
#  (215, 'agronomi', 0, 1, 0, 0, 0),
#  (216, 'agronomia', 0, 1, 0, 0, 0),
#  (217, 'ahava', 0, 1, 0, 0, 0),
#  (218, 'ahavoittaa', 1, 0, 0, 0, 0),
#  (219, 'ahavoitua', 1, 0, 0, 0, 0),
#  (220, 'ahdas', 0, 0, 1, 0, 0),
#  (221, 'ahdasmielinen', 0, 0, 1, 0, 0),
#  (222, 'ahde', 0, 1, 0, 0, 0),
#  (223, 'ahdekaunokki', 0, 1, 0, 0, 0),
#  (224, 'ahdin', 0, 1, 0, 0, 0),
#  (225, 'ahdinko', 0, 1, 0, 0, 0),
#  (226, 'ahdistaa', 1, 0, 0, 0, 0),
#  (227, 'ahdistaja', 0, 1, 0, 0, 0),
#  (228, 'ahdistelija', 0, 1, 0, 0, 0),
#  (229, 'ahdistella', 1, 0, 0, 0, 0),
#  (230, 'ahdistelu', 0, 1, 0, 0, 0),
#  (231, 'ahdistua', 1, 0, 0, 0, 0),
#  (232, 'ahdistunut', 0, 0, 0, 0, 0),
#  (233, 'ahdistus', 0, 1, 0, 0, 0),
#  (234, 'aherrus', 0, 1, 0, 0, 0),
#  (235, 'ahertaa', 1, 0, 0, 0, 0),
#  (236, 'ahertaja', 0, 1, 0, 0, 0),
#  (237, 'ahjo', 0, 1, 0, 0, 0),
#  (238, 'ahkera', 0, 0, 1, 0, 0),
#  (239, 'ahkeroida', 1, 0, 0, 0, 0),
#  (240, 'ahkerointi', 0, 1, 0, 0, 0),
#  (241, 'ahkeruus', 0, 1, 0, 0, 0),
#  (242, 'ahkio', 0, 1, 0, 0, 0),
#  (243, 'ahma', 0, 1, 0, 0, 0),
#  (244, 'ahmatti', 0, 1, 0, 0, 0),
#  (245, 'ahmia', 1, 0, 0, 0, 0),
#  (246, 'ahminta', 0, 1, 0, 0, 0),
#  (247, 'ahnas', 0, 0, 1, 0, 0),
#  (248, 'ahnaus', 0, 1, 0, 0, 0),
#  (249, 'ahne', 0, 0, 1, 0, 0),
#  (250, 'ahnehdinta', 0, 1, 0, 0, 0),
#  (251, 'ahnehtia', 1, 0, 0, 0, 0),
#  (252, 'ahnehtija', 0, 1, 0, 0, 0),
#  (253, 'ahneus', 0, 1, 0, 0, 0),
#  (254, 'aho', 0, 1, 0, 0, 0),
#  (255, 'ahomansikka', 0, 1, 0, 0, 0),
#  (256, 'ahrain', 0, 1, 0, 0, 0),
#  (257, 'ahtaa', 1, 0, 0, 0, 0),
#  (258, 'ahtaaja', 0, 1, 0, 0, 0),
#  (259, 'ahtaus', 0, 1, 0, 0, 0),
#  (260, 'ahtausliike', 0, 1, 0, 0, 0),
#  (261, 'ahtautua', 1, 0, 0, 0, 0),
#  (262, 'ahteri', 0, 1, 0, 0, 0),
#  (263, 'ahti', 0, 1, 0, 0, 0),
#  (264, 'ahtojää', 0, 1, 0, 0, 0),
#  (265, 'ahtopaine', 0, 1, 0, 0, 0),
#  (266, 'ahven', 0, 1, 0, 0, 0),
#  (267, 'ahvenvita', 0, 1, 0, 0, 0),
#  (268, 'aidanrako', 0, 1, 0, 0, 0),
#  (269, 'aidata', 1, 0, 0, 0, 0),
#  (270, 'aids', 0, 1, 0, 0, 0),
#  (271, 'aie', 0, 1, 0, 0, 0),
#  (272, 'aiempi', 0, 0, 1, 0, 0),
#  (273, 'aiesopimus', 0, 1, 0, 0, 0),
#  (274, 'aihe', 0, 1, 0, 0, 0),
#  (275, 'aiheellinen', 0, 0, 1, 0, 0),
#  (276, 'aiheellisuus', 0, 1, 0, 0, 0),
#  (277, 'aiheeton', 0, 0, 1, 0, 0),
#  (278, 'aiheettomuus', 0, 1, 0, 0, 0),
#  (279, 'aihelma', 0, 1, 0, 0, 0),
#  (280, 'aiheuttaa', 1, 0, 0, 0, 0),
#  (281, 'aiheuttaja', 0, 1, 0, 0, 0),
#  (282, 'aiheutua', 1, 0, 0, 0, 0),
#  (283, 'aiheutus', 0, 1, 0, 0, 0),
#  (284, 'aihio', 0, 1, 0, 0, 0),
#  (285, 'aikaansaada', 1, 0, 0, 0, 0),
#  (286, 'aikaansaannos', 0, 1, 0, 0, 0),
#  (287, 'aikaansaava', 0, 0, 1, 0, 0),
#  (288, 'aikaero', 0, 1, 0, 0, 0),
#  (289, 'aikaihminen', 0, 1, 0, 0, 0),
#  (290, 'aikailla', 1, 0, 0, 0, 0),
#  (291, 'aikailu', 0, 1, 0, 0, 0),
#  (292, 'aikainen', 0, 0, 1, 0, 0),
#  (293, 'aikaistaa', 1, 0, 0, 0, 0),
#  (294, 'aikaistus', 0, 1, 0, 0, 0),
#  (295, 'aikaisuus', 0, 1, 0, 0, 0),
#  (296, 'aikajärjestys', 0, 1, 0, 0, 0),
#  (297, 'aikakausi', 0, 1, 0, 0, 0),
#  (298, 'aikakauskirja', 0, 1, 0, 0, 0),
#  (299, 'aikakauslehti', 0, 1, 0, 0, 0),
#  (300, 'aikakirja', 0, 1, 0, 0, 0),
#  (301, 'aikakone', 0, 1, 0, 0, 0),
#  (302, 'aikalainen', 0, 1, 0, 0, 0),
#  (303, 'aikalisä', 0, 1, 0, 0, 0),
#  (304, 'aikaluokka', 0, 1, 0, 0, 0),
#  (305, 'aikamerkki', 0, 1, 0, 0, 0),
#  (306, 'aikamies', 0, 1, 0, 0, 0),
#  (307, 'aikamiespoika', 0, 1, 0, 0, 0),
#  (308, 'aikamitta', 0, 1, 0, 0, 0),
#  (309, 'aikamoinen', 0, 0, 1, 0, 0),
#  (310, 'aikamuoto', 0, 1, 0, 0, 0),
#  (311, 'aikapommi', 0, 1, 0, 0, 0),
#  (312, 'aikapula', 0, 1, 0, 0, 0),
#  (313, 'aikataulu', 0, 1, 0, 0, 0),
#  (314, 'aikautus', 0, 1, 0, 0, 0),
#  (315, 'aikavyöhyke', 0, 1, 0, 0, 0),
#  (316, 'aikaväli', 0, 1, 0, 0, 0),
#  (317, 'aikayksikkö', 0, 1, 0, 0, 0),
#  (318, 'aikoa', 1, 0, 0, 0, 0),
#  (319, 'aikomus', 0, 1, 0, 0, 0),
#  (320, 'aikuinen', 0, 1, 1, 0, 0),
#  (321, 'aikuistua', 1, 0, 0, 0, 0),
#  (322, 'aikuisuus', 0, 1, 0, 0, 0),
#  (323, 'ailahdella', 1, 0, 0, 0, 0),
#  (324, 'ailahdus', 0, 1, 0, 0, 0),
#  (325, 'ailahtelu', 0, 1, 0, 0, 0),
#  (326, 'aina', 0, 0, 0, 0, 0),
#  (327, 'ainainen', 0, 0, 1, 0, 0),
#  (328, 'ainavihanta', 0, 0, 1, 0, 0),
#  (329, 'aine', 0, 1, 0, 0, 0),
#  (330, 'aineellinen', 0, 0, 1, 0, 0),
#  (331, 'aineellisuus', 0, 1, 0, 0, 0),
#  (332, 'aineenkoetus', 0, 1, 0, 0, 0),
#  (333, 'aineeton', 0, 0, 1, 0, 0),
#  (334, 'aineettomuus', 0, 1, 0, 0, 0),
#  (335, 'aineisto', 0, 1, 0, 0, 0),
#  (336, 'ainekirjoitus', 0, 1, 0, 0, 0),
#  (337, 'ainemäärä', 0, 1, 0, 0, 0),
#  (338, 'aines', 0, 1, 0, 0, 0),
#  (339, 'ainesana', 0, 1, 0, 0, 0),
#  (340, 'ainesosa', 0, 1, 0, 0, 0),
#  (341, 'ainespuu', 0, 1, 0, 0, 0),
#  (342, 'aino', 0, 1, 0, 0, 0),
#  (343, 'ainoa', 0, 0, 1, 0, 0),
#  (344, 'ainokainen', 0, 1, 0, 0, 0),
#  (345, 'ainu', 0, 1, 0, 0, 0),
#  (346, 'aioli', 0, 1, 0, 0, 0),
#  (347, 'airo', 0, 1, 0, 0, 0),
#  (348, 'aironlapa', 0, 1, 0, 0, 0),
#  (349, 'airut', 0, 1, 0, 0, 0),
#  (350, 'aisa', 0, 1, 0, 0, 0),
#  (351, 'aisapari', 0, 1, 0, 0, 0),
#  (352, 'aisti', 0, 1, 0, 0, 0),
#  (353, 'aistia', 1, 0, 0, 0, 0),
#  (354, 'aistiharha', 0, 1, 0, 0, 0),
#  (355, 'aistihavainto', 0, 1, 0, 0, 0),
#  (356, 'aistikas', 0, 0, 1, 0, 0),
#  (357, 'aistikkuus', 0, 1, 0, 0, 0),
#  (358, 'aistillinen', 0, 0, 1, 0, 0),
#  (359, 'aistillisuus', 0, 1, 0, 0, 0),
#  (360, 'aistimus', 0, 1, 0, 0, 0),
#  (361, 'aistin', 0, 1, 0, 0, 0),
#  (362, 'aistinelin', 0, 1, 0, 0, 0),
#  (363, 'aistinsolu', 0, 1, 0, 0, 0),
#  (364, 'aita', 0, 1, 0, 0, 0),
#  (365, 'aitajuoksija', 0, 1, 0, 0, 0),
#  (366, 'aitajuoksu', 0, 1, 0, 0, 0),
#  (367, 'aitaus', 0, 1, 0, 0, 0),
#  (368, 'aitio', 0, 1, 0, 0, 0),
#  (369, 'aito', 0, 0, 1, 0, 0),
#  (370, 'aitoa', 1, 0, 0, 0, 0),
#  (371, 'aitoamaryllis', 0, 1, 0, 0, 0),
#  (372, 'aitous', 0, 1, 0, 0, 0),
#  (373, 'aitovieri', 0, 1, 0, 0, 0),
#  (374, 'aitta', 0, 1, 0, 0, 0),
#  (375, 'aituri', 0, 1, 0, 0, 0),
#  (376, 'aivastaa', 1, 0, 0, 0, 0),
#  (377, 'aivastella', 1, 0, 0, 0, 0),
#  (378, 'aivastus', 0, 1, 0, 0, 0),
#  (379, 'aivina', 0, 1, 0, 0, 0),
#  (380, 'aivo', 0, 1, 0, 0, 0),
#  (381, 'aivoaine', 0, 1, 0, 0, 0),
#  (382, 'aivofilmi', 0, 1, 0, 0, 0),
#  (383, 'aivohalvaus', 0, 1, 0, 0, 0),
#  (384, 'aivoitus', 0, 1, 0, 0, 0),
#  (385, 'aivokalvo', 0, 1, 0, 0, 0),
#  (386, 'aivokammio', 0, 1, 0, 0, 0),
#  (387, 'aivokasvain', 0, 1, 0, 0, 0),
#  (388, 'aivokuolema', 0, 1, 0, 0, 0),
#  (389, 'aivokuollut', 0, 0, 1, 0, 0),
#  (390, 'aivokuori', 0, 1, 0, 0, 0),
#  (391, 'aivokuume', 0, 1, 0, 0, 0),
#  (392, 'aivokuva', 0, 1, 0, 0, 0),
#  (393, 'aivokäyrä', 0, 1, 0, 0, 0),
#  (394, 'aivolisäke', 0, 1, 0, 0, 0),
#  (395, 'aivopesu', 0, 1, 0, 0, 0),
#  (396, 'aivopuolisko', 0, 1, 0, 0, 0),
#  (397, 'aivoriihi', 0, 1, 0, 0, 0),
#  (398, 'aivorunko', 0, 1, 0, 0, 0),
#  (399, 'aivosairaus', 0, 1, 0, 0, 0),
#  (400, 'aivosolu', 0, 1, 0, 0, 0),
#  (401, 'aivot', 0, 1, 0, 0, 0),
#  (402, 'aivotoiminta', 0, 1, 0, 0, 0),
#  (403, 'aivotulehdus', 0, 1, 0, 0, 0),
#  (404, 'aivotyö', 0, 1, 0, 0, 0),
#  (405, 'aivotärähdys', 0, 1, 0, 0, 0),
#  (406, 'aivovamma', 0, 1, 0, 0, 0),
#  (407, 'aivovaurio', 0, 1, 0, 0, 0),
#  (408, 'aivovuoto', 0, 1, 0, 0, 0),
#  (409, 'ajaa', 1, 0, 0, 0, 0),
#  (410, 'ajaantua', 1, 0, 0, 0, 0),
#  (411, 'ajaja', 0, 1, 0, 0, 0),
#  (412, 'ajallinen', 0, 0, 1, 0, 0),
#  (413, 'ajallisuus', 0, 1, 0, 0, 0),
#  (414, 'ajanhukka', 0, 1, 0, 0, 0),
#  (415, 'ajanjakso', 0, 1, 0, 0, 0),
#  (416, 'ajankohta', 0, 1, 0, 0, 0),
#  (417, 'ajankohtainen', 0, 0, 1, 0, 0),
#  (418, 'ajankulu', 0, 1, 0, 0, 0),
#  (419, 'ajankuva', 0, 1, 0, 0, 0),
#  (420, 'ajanlasku', 0, 1, 0, 0, 0),
#  (421, 'ajanmukainen', 0, 0, 1, 0, 0),
#  (422, 'ajanmukaisuus', 0, 1, 0, 0, 0),
#  (423, 'ajanottaja', 0, 1, 0, 0, 0),
#  (424, 'ajanotto', 0, 1, 0, 0, 0),
#  (425, 'ajanpuute', 0, 1, 0, 0, 0),
#  (426, 'ajantasainen', 0, 0, 1, 0, 0),
#  (427, 'ajantasaistus', 0, 1, 0, 0, 0),
#  (428, 'ajantasaisuus', 0, 1, 0, 0, 0),
#  (429, 'ajanviete', 0, 1, 0, 0, 0),
#  (430, 'ajastaa', 1, 0, 0, 0, 0),
#  (431, 'ajastaika', 0, 1, 0, 0, 0),
#  (432, 'ajastin', 0, 1, 0, 0, 0),
#  (433, 'ajastus', 0, 1, 0, 0, 0),
#  (434, 'ajatella', 1, 0, 0, 0, 0),
#  (435, 'ajatelma', 0, 1, 0, 0, 0),
#  (436, 'ajatollah', 0, 1, 0, 0, 0),
#  (437, 'ajaton', 0, 0, 1, 0, 0),
#  (438, 'ajattaa', 1, 0, 0, 0, 0),
#  (439, 'ajattelematon', 0, 0, 1, 0, 0),
#  (440, 'ajattelija', 0, 1, 0, 0, 0),
#  (441, 'ajattelu', 0, 1, 0, 0, 0),
#  (442, 'ajattelukyky', 0, 1, 0, 0, 0),
#  (443, 'ajattomuus', 0, 1, 0, 0, 0),
#  (444, 'ajatukseton', 0, 0, 1, 0, 0),
#  (445, 'ajatus', 0, 1, 0, 0, 0),
#  (446, 'ajatuskupla', 0, 1, 0, 0, 0),
#  (447, 'ajatusmaailma', 0, 1, 0, 0, 0),
#  (448, 'ajatustapa', 0, 1, 0, 0, 0),
#  (449, 'ajatusviiva', 0, 1, 0, 0, 0),
#  (450, 'ajatusvirhe', 0, 1, 0, 0, 0),
#  (451, 'ajautua', 1, 0, 0, 0, 0),
#  (452, 'ajella', 1, 0, 0, 0, 0),
#  (453, 'ajelu', 0, 1, 0, 0, 0),
#  (454, 'ajo', 0, 1, 0, 0, 0),
#  (455, 'ajoankkuri', 0, 1, 0, 0, 0),
#  (456, 'ajoittaa', 1, 0, 0, 0, 0),
#  (457, 'ajoittainen', 0, 0, 1, 0, 0),
#  (458, 'ajoittaisuus', 0, 1, 0, 0, 0),
#  (459, 'ajoittua', 1, 0, 0, 0, 0),
#  (460, 'ajoitus', 0, 1, 0, 0, 0),
#  (461, 'ajojahti', 0, 1, 0, 0, 0),
#  (462, 'ajojää', 0, 1, 0, 0, 0),
#  (463, 'ajokaista', 0, 1, 0, 0, 0),
#  (464, 'ajokas', 0, 1, 0, 0, 0),
#  (465, 'ajokeli', 0, 1, 0, 0, 0),
#  (466, 'ajokki', 0, 1, 0, 0, 0),
#  (467, 'ajokoe', 0, 1, 0, 0, 0),
#  (468, 'ajokoira', 0, 1, 0, 0, 0),
#  (469, 'ajokortti', 0, 1, 0, 0, 0),
#  (470, 'ajolähtö', 0, 1, 0, 0, 0),
#  (471, 'ajomatka', 0, 1, 0, 0, 0),
#  (472, 'ajometsästys', 0, 1, 0, 0, 0),
#  (473, 'ajomies', 0, 1, 0, 0, 0),
#  (474, 'ajomiina', 0, 1, 0, 0, 0),
#  (475, 'ajonestolaite', 0, 1, 0, 0, 0),
#  (476, 'ajoneuvo', 0, 1, 0, 0, 0),
#  (477, 'ajopeli', 0, 1, 0, 0, 0),
#  (478, 'ajoporo', 0, 1, 0, 0, 0),
#  (479, 'ajopuu', 0, 1, 0, 0, 0),
#  (480, 'ajopäiväkirja', 0, 1, 0, 0, 0),
#  (481, 'ajos', 0, 1, 0, 0, 0),
#  (482, 'ajotie', 0, 1, 0, 0, 0),
#  (483, 'ajotilanne', 0, 1, 0, 0, 0),
#  (484, 'ajoverkko', 0, 1, 0, 0, 0),
#  (485, 'ajuri', 0, 1, 0, 0, 0),
#  (486, 'ajuruoho', 0, 1, 0, 0, 0),
#  (487, 'akaatti', 0, 1, 0, 0, 0),
#  (488, 'akana', 0, 1, 0, 0, 0),
#  (489, 'akankaali', 0, 1, 0, 0, 0),
#  (490, 'akantti', 0, 1, 0, 0, 0),
#  (491, 'akanvirta', 0, 1, 0, 0, 0),
#  (492, 'akasia', 0, 1, 0, 0, 0),
#  (493, 'akateemikko', 0, 1, 0, 0, 0),
#  (494, 'akateeminen', 0, 0, 1, 0, 0),
#  (495, 'akateemisuus', 0, 1, 0, 0, 0),
#  (496, 'akatemia', 0, 1, 0, 0, 0),
#  (497, 'akileija', 0, 1, 0, 0, 0),
#  (498, 'akillesjänne', 0, 1, 0, 0, 0),
#  (499, 'akka', 0, 1, 0, 0, 0),
#  (500, 'akkamainen', 0, 0, 1, 0, 0),
#  (501, 'akkamaisuus', 0, 1, 0, 0, 0),
#  (502, 'akkavalta', 0, 1, 0, 0, 0),
#  (503, 'akkommodaatio', 0, 1, 0, 0, 0),
#  (504, 'akkreditoida', 1, 0, 0, 0, 0),
#  (505, 'akku', 0, 1, 0, 0, 0),
#  (506, 'akkuna', 0, 1, 0, 0, 0),
#  (507, 'akkusatiivi', 0, 1, 0, 0, 0),
#  (508, 'akne', 0, 1, 0, 0, 0),
#  (509, 'akordi', 0, 1, 0, 0, 0),
#  (510, 'akrobaatti', 0, 1, 0, 0, 0),
#  (511, 'akrobatia', 0, 1, 0, 0, 0),
#  (512, 'akronyymi', 0, 1, 0, 0, 0),
#  (513, 'akseli', 0, 1, 0, 0, 0),
#  (514, 'akselivallat', 0, 1, 0, 0, 0),
#  (515, 'akseliväli', 0, 1, 0, 0, 0),
#  (516, 'aksentti', 0, 1, 0, 0, 0),
#  (517, 'aksepti', 0, 1, 0, 0, 0),
#  (518, 'akseptointi', 0, 1, 0, 0, 0),
#  (519, 'aksiaalinen', 0, 0, 1, 0, 0),
#  (520, 'aksiaalisuus', 0, 1, 0, 0, 0),
#  (521, 'aksiooma', 0, 1, 0, 0, 0),
#  (522, 'akti', 0, 1, 0, 0, 0),
#  (523, 'aktiivi', 0, 1, 1, 0, 0),
#  (524, 'aktiivihiili', 0, 1, 0, 0, 0),
#  (525, 'aktiivinen', 0, 0, 1, 0, 0),
#  (526, 'aktiivisuus', 0, 1, 0, 0, 0),
#  (527, 'aktio', 0, 1, 0, 0, 0),
#  (528, 'aktivismi', 0, 1, 0, 0, 0),
#  (529, 'aktivisti', 0, 1, 0, 0, 0),
#  (530, 'aktiviteetti', 0, 1, 0, 0, 0),
#  (531, 'aktivoida', 1, 0, 0, 0, 0),
#  (532, 'aktivointi', 0, 1, 0, 0, 0),
#  (533, 'aktivoitua', 1, 0, 0, 0, 0),
#  (534, 'aktuaalisuus', 0, 1, 0, 0, 0),
#  (535, 'aktuaari', 0, 1, 0, 0, 0),
#  (536, 'aktualisointi', 0, 1, 0, 0, 0),
#  (537, 'akupunktuuri', 0, 1, 0, 0, 0),
#  (538, 'akustiikka', 0, 1, 0, 0, 0),
#  (539, 'akustinen', 0, 0, 1, 0, 0),
#  (540, 'akusto', 0, 1, 0, 0, 0),
#  (541, 'akvaario', 0, 1, 0, 0, 0),
#  (542, 'akvaariokala', 0, 1, 0, 0, 0),
#  (543, 'akvaariokasvi', 0, 1, 0, 0, 0),
#  (544, 'akvamariini', 0, 1, 1, 0, 0),
#  (545, 'akvarelli', 0, 1, 0, 0, 0),
#  (546, 'akvatinta', 0, 1, 0, 0, 0),
#  (547, 'akvaviitti', 0, 1, 0, 0, 0),
#  (548, 'ala', 0, 1, 0, 0, 0),
#  (549, 'ala-arvoinen', 0, 1, 1, 0, 0),
#  (550, 'ala-arvoisuus', 0, 1, 0, 0, 0),
#  (551, 'ala-aste', 0, 1, 0, 0, 0),
#  (552, 'alabasteri', 0, 1, 0, 0, 0),
#  (553, 'aladobi', 0, 1, 0, 0, 0),
#  (554, 'alahanka', 0, 1, 0, 0, 0),
#  (555, 'alahuone', 0, 1, 0, 0, 0),
#  (556, 'alahuuli', 0, 1, 0, 0, 0),
#  (557, 'alaikäinen', 0, 0, 1, 0, 0),
#  (558, 'alaikäisyys', 0, 1, 0, 0, 0),
#  (559, 'alainen', 0, 1, 1, 0, 0),
#  (560, 'alaisuus', 0, 1, 0, 0, 0),
#  (561, 'alajuoksu', 0, 1, 0, 0, 0),
#  (562, 'alakerta', 0, 1, 0, 0, 0),
#  (563, 'alakoukku', 0, 1, 0, 0, 0),
#  (564, 'alakoulu', 0, 1, 0, 0, 0),
#  (565, 'alakulo', 0, 1, 0, 0, 0),
#  (566, 'alakuloinen', 0, 0, 1, 0, 0),
#  (567, 'alakuloisuus', 0, 1, 0, 0, 0),
#  (568, 'alakulttuuri', 0, 1, 0, 0, 0),
#  (569, 'alakuntoisuus', 0, 1, 0, 0, 0),
#  (570, 'alalaji', 0, 1, 0, 0, 0),
#  (571, 'alalanka', 0, 1, 0, 0, 0),
#  (572, 'alaleuka', 0, 1, 0, 0, 0),
#  (573, 'alaleukaluu', 0, 1, 0, 0, 0),
#  (574, 'alaluokka', 0, 1, 0, 0, 0),
#  (575, 'alamaa', 0, 1, 0, 0, 0),
#  (576, 'alamaailma', 0, 1, 0, 0, 0),
#  (577, 'alamainen', 0, 1, 0, 0, 0),
#  (578, 'alamaisuus', 0, 1, 0, 0, 0),
#  (579, 'alamäki', 0, 1, 0, 0, 0),
#  (580, 'alanko', 0, 1, 0, 0, 0),
#  (581, 'alanurkka', 0, 1, 0, 0, 0),
#  (582, 'alaosa', 0, 1, 0, 0, 0),
#  (583, 'alaotsikko', 0, 1, 0, 0, 0),
#  (584, 'alapesu', 0, 1, 0, 0, 0),
#  (585, 'alapeti', 0, 1, 0, 0, 0),
#  (586, 'alapohja', 0, 1, 0, 0, 0),
#  (587, 'alapuoli', 0, 1, 0, 0, 0),
#  (588, 'alapuolinen', 0, 0, 1, 0, 0),
#  (589, 'alapää', 0, 1, 0, 0, 0),
#  (590, 'alaraaja', 0, 1, 0, 0, 0),
#  (591, 'alareuna', 0, 1, 0, 0, 0),
#  (592, 'alasajo', 0, 1, 0, 0, 0),
#  (593, 'alasin', 0, 1, 0, 0, 0),
#  (594, 'alastomuus', 0, 1, 0, 0, 0),
#  (595, 'alaston', 0, 1, 1, 0, 0),
#  (596, 'alastonkuva', 0, 1, 0, 0, 0),
#  (597, 'alastonmalli', 0, 1, 0, 0, 0),
#  (598, 'alatyyli', 0, 1, 0, 0, 0),
#  (599, 'alatyylinen', 0, 0, 1, 0, 0),
#  (600, 'alava', 0, 0, 1, 0, 0),
#  (601, 'alaviite', 0, 1, 0, 0, 0),
#  (602, 'alavireinen', 0, 0, 1, 0, 0),
#  (603, 'alavireisyys', 0, 1, 0, 0, 0),
#  (604, 'alavirta', 0, 1, 0, 0, 0),
#  (605, 'alavuus', 0, 1, 0, 0, 0),
#  (606, 'alba', 0, 1, 0, 0, 0),
#  (607, 'albaani', 0, 1, 0, 0, 0),
#  (608, 'albanialainen', 0, 1, 1, 0, 0),
#  (609, 'albatrossi', 0, 1, 0, 0, 0),
#  (610, 'albiino', 0, 1, 1, 0, 0),
#  (611, 'albumi', 0, 1, 0, 0, 0),
#  (612, 'ale', 0, 0, 0, 0, 0),
#  (613, 'alempi', 0, 0, 1, 0, 0),
#  (614, 'alenema', 0, 1, 0, 0, 0),
#  (615, 'aleneva', 0, 0, 0, 0, 0),
#  (616, 'alennus', 0, 1, 0, 0, 0),
#  (617, 'alennusmerkki', 0, 1, 0, 0, 0),
#  (618, 'alennusmyynti', 0, 1, 0, 0, 0),
#  (619, 'alennustila', 0, 1, 0, 0, 0),
#  (620, 'alentaa', 1, 0, 0, 0, 0),
#  (621, 'alentava', 0, 0, 0, 0, 0),
#  (622, 'alentua', 1, 0, 0, 0, 0),
#  (623, 'alentuva', 0, 0, 1, 0, 0),
#  (624, 'alentuvainen', 0, 0, 1, 0, 0),
#  (625, 'alentuvaisuus', 0, 1, 0, 0, 0),
#  (626, 'alentuvuus', 0, 1, 0, 0, 0),
#  (627, 'aleta', 1, 0, 0, 0, 0),
#  (628, 'alfa', 0, 1, 0, 0, 0),
#  (629, 'alfahiukkanen', 0, 1, 0, 0, 0),
#  (630, 'alfasäteily', 0, 1, 0, 0, 0),
#  (631, 'algebra', 0, 1, 0, 0, 0),
#  (632, 'algebrallinen', 0, 0, 1, 0, 0),
#  (633, 'algoritmi', 0, 1, 0, 0, 0),
#  (634, 'alhainen', 0, 0, 1, 0, 0),
#  (635, 'alhaisuus', 0, 1, 0, 0, 0),
#  (636, 'alho', 0, 1, 0, 0, 0),
#  (637, 'aliarvioida', 1, 0, 0, 0, 0),
#  (638, 'aliarvostaa', 1, 0, 0, 0, 0),
#  (639, 'alihankinta', 0, 1, 0, 0, 0),
#  (640, 'alihankkija', 0, 1, 0, 0, 0),
#  (641, 'alijäämä', 0, 1, 0, 0, 0),
#  (642, 'alikehittynyt', 0, 0, 1, 0, 0),
#  (643, 'alikersantti', 0, 1, 0, 0, 0),
#  (644, 'alikulku', 0, 1, 0, 0, 0),
#  (645, 'alikäytävä', 0, 1, 0, 0, 0),
#  (646, 'aliluutnantti', 0, 1, 0, 0, 0),
#  (647, 'alimitoittaa', 1, 0, 0, 0, 0),
#  (648, 'alin', 0, 0, 1, 0, 0),
#  (649, 'alioikeus', 0, 1, 0, 0, 0),
#  (650, 'alipaine', 0, 1, 0, 0, 0),
#  (651, 'alipaino', 0, 1, 0, 0, 0),
#  (652, 'alipainoinen', 0, 0, 1, 0, 0),
#  (653, 'alipainoisuus', 0, 1, 0, 0, 0),
#  (654, 'aliravitsemus', 0, 1, 0, 0, 0),
#  (655, 'aliravittu', 0, 0, 1, 0, 0),
#  (656, 'alistaa', 1, 0, 0, 0, 0),
#  (657, 'alisteinen', 0, 0, 1, 0, 0),
#  (658, 'alisteisuus', 0, 1, 0, 0, 0),
#  (659, 'alistua', 1, 0, 0, 0, 0),
#  (660, 'alistus', 0, 1, 0, 0, 0),
#  (661, 'alistussuhde', 0, 1, 0, 0, 0),
#  (662, 'alistuva', 0, 0, 0, 0, 0),
#  (663, 'alistuvaisuus', 0, 1, 0, 0, 0),
#  (664, 'alistuvuus', 0, 1, 0, 0, 0),
#  (665, 'alitajunta', 0, 1, 0, 0, 0),
#  (666, 'alittaa', 1, 0, 0, 0, 0),
#  (667, 'alitus', 0, 1, 0, 0, 0),
#  (668, 'alityöllisyys', 0, 1, 0, 0, 0),
#  (669, 'aliupseeri', 0, 1, 0, 0, 0),
#  (670, 'alivoimaisuus', 0, 1, 0, 0, 0),
#  (671, 'alkaa', 1, 0, 0, 0, 0),
#  (672, 'alkaja', 0, 1, 0, 0, 0),
#  (673, 'alkajaiset', 0, 1, 0, 0, 0),
#  (674, 'alkali', 0, 1, 0, 0, 0),
#  (675, 'alkalisuus', 0, 1, 0, 0, 0),
#  (676, 'alkaloidi', 0, 1, 0, 0, 0),
#  (677, 'alkeellinen', 0, 0, 1, 0, 0),
#  (678, 'alkeellisuus', 0, 1, 0, 0, 0),
#  (679, 'alkeet', 0, 1, 0, 0, 0),
#  (680, 'alkeiskirja', 0, 1, 0, 0, 0),
#  (681, 'alkeiskurssi', 0, 1, 0, 0, 0),
#  (682, 'alkeislehti', 0, 1, 0, 0, 0),
#  (683, 'alkeisvaraus', 0, 1, 0, 0, 0),
#  (684, 'alkemia', 0, 1, 0, 0, 0),
#  (685, 'alkemisti', 0, 1, 0, 0, 0),
#  (686, 'alkio', 0, 1, 0, 0, 0),
#  (687, 'alkiolaisuus', 0, 1, 0, 0, 0),
#  (688, 'alkionsiirto', 0, 1, 0, 0, 0),
#  (689, 'alkoholi', 0, 1, 0, 0, 0),
#  (690, 'alkoholijuoma', 0, 1, 0, 0, 0),
#  (691, 'alkoholismi', 0, 1, 0, 0, 0),
#  (692, 'alkoholisti', 0, 1, 0, 0, 0),
#  (693, 'alkoholiton', 0, 0, 1, 0, 0),
#  (694, 'alkometri', 0, 1, 0, 0, 0),
#  (695, 'alkovi', 0, 1, 0, 0, 0),
#  (696, 'alku', 0, 1, 0, 0, 0),
#  (697, 'alkuaine', 0, 1, 0, 0, 0),
#  (698, 'alkuasukas', 0, 1, 0, 0, 0),
#  (699, 'alkueliö', 0, 1, 0, 0, 0),
#  (700, 'alkueläin', 0, 1, 0, 0, 0),
#  (701, 'alkuhärkä', 0, 1, 0, 0, 0),
#  (702, 'alkuilta', 0, 1, 0, 0, 0),
#  (703, 'alkukantainen', 0, 1, 0, 0, 0),
#  (704, 'alkukesä', 0, 1, 0, 0, 0),
#  (705, 'alkukevät', 0, 1, 0, 0, 0),
#  (706, 'alkukieli', 0, 1, 0, 0, 0),
#  (707, 'alkukielinen', 0, 0, 1, 0, 0),
#  (708, 'alkukirjain', 0, 1, 0, 0, 0),
#  (709, 'alkukirkko', 0, 1, 0, 0, 0),
#  (710, 'alkukoti', 0, 1, 0, 0, 0),
#  (711, 'alkulima', 0, 1, 0, 0, 0),
#  (712, 'alkuluku', 0, 1, 0, 0, 0),
#  (713, 'alkulähde', 0, 1, 0, 0, 0),
#  (714, 'alkumatka', 0, 1, 0, 0, 0),
#  (715, 'alkumuoto', 0, 1, 0, 0, 0),
#  (716, 'alkupala', 0, 1, 0, 0, 0),
#  (717, 'alkuperä', 0, 1, 0, 0, 0),
#  (718, 'alkuperäinen', 0, 0, 1, 0, 0),
#  (719, 'alkuperäisyys', 0, 1, 0, 0, 0),
#  (720, 'alkuperämaa', 0, 1, 0, 0, 0),
#  (721, 'alkupääoma', 0, 1, 0, 0, 0),
#  (722, 'alkuruoka', 0, 1, 0, 0, 0),
#  (723, 'alkuräjähdys', 0, 1, 0, 0, 0),
#  (724, 'alkusanat', 0, 1, 0, 0, 0),
#  (725, 'alkusointu', 0, 1, 0, 0, 0),
#  (726, 'alkusoitto', 0, 1, 0, 0, 0),
#  (727, 'alkusyksy', 0, 1, 0, 0, 0),
#  (728, 'alkusynty', 0, 1, 0, 0, 0),
#  (729, 'alkusysäys', 0, 1, 0, 0, 0),
#  (730, 'alkutalvi', 0, 1, 0, 0, 0),
#  (731, 'alkutekijä', 0, 1, 0, 0, 0),
#  (732, 'alkuteksti', 0, 1, 0, 0, 0),
#  (733, 'alkuteos', 0, 1, 0, 0, 0),
#  (734, 'alkutuotanto', 0, 1, 0, 0, 0),
#  (735, 'alkuunpanija', 0, 1, 0, 0, 0),
#  (736, 'alkuvaihe', 0, 1, 0, 0, 0),
#  (737, 'alkuviikko', 0, 1, 0, 0, 0),
#  (738, 'alkuvuosi', 0, 1, 0, 0, 0),
#  (739, 'allakka', 0, 1, 0, 0, 0),
#  (740, 'allas', 0, 1, 0, 0, 0),
#  (741, 'allatiivi', 0, 1, 0, 0, 0),
#  (742, 'allegoria', 0, 1, 0, 0, 0),
#  (743, 'allegorinen', 0, 0, 1, 0, 0),
#  (744, 'allegorisuus', 0, 1, 0, 0, 0),
#  (745, 'allegro', 0, 1, 0, 0, 0),
#  (746, 'allekirjoitus', 0, 1, 0, 0, 0),
#  (747, 'allergeeni', 0, 1, 0, 0, 0),
#  (748, 'allergeeninen', 0, 1, 0, 0, 0),
#  (749, 'allergia', 0, 1, 0, 0, 0),
#  (750, 'allergikko', 0, 1, 0, 0, 0),
#  (751, 'allerginen', 0, 0, 1, 0, 0),
#  (752, 'allergisoida', 1, 0, 0, 0, 0),
#  (753, 'allergisuus', 0, 1, 0, 0, 0),
#  (754, 'alleviivata', 1, 0, 0, 0, 0),
#  (755, 'alli', 0, 1, 0, 0, 0),
#  (756, 'allianssi', 0, 1, 0, 0, 0),
#  (757, 'alligaattori', 0, 1, 0, 0, 0),
#  (758, 'allikko', 0, 1, 0, 0, 0),
#  (759, 'allitteraatio', 0, 1, 0, 0, 0),
#  (760, 'allokaatio', 0, 1, 0, 0, 0),
#  (761, 'allokoida', 1, 0, 0, 0, 0),
#  (762, 'allokointi', 0, 1, 0, 0, 0),
#  (763, 'almanakka', 0, 1, 0, 0, 0),
#  (764, 'almu', 0, 1, 0, 0, 0),
#  (765, 'aloite', 0, 1, 0, 0, 0),
#  (766, 'aloitekyvytön', 0, 0, 1, 0, 0),
#  (767, 'aloitella', 1, 0, 0, 0, 0),
#  (768, 'aloiteoikeus', 0, 1, 0, 0, 0),
#  (769, 'aloittaa', 1, 0, 0, 0, 0),
#  (770, 'aloittaja', 0, 1, 0, 0, 0),
#  (771, 'aloittelija', 0, 1, 0, 0, 0),
#  (772, 'aloitus', 0, 1, 0, 0, 0),
#  (773, 'alokas', 0, 1, 0, 0, 0),
#  (774, 'alokasmainen', 0, 0, 1, 0, 0),
#  (775, 'alpi', 0, 1, 0, 0, 0),
#  (776, 'alpinismi', 0, 1, 0, 0, 0),
#  (777, 'alpinisti', 0, 1, 0, 0, 0),
#  (778, 'alppihiihto', 0, 1, 0, 0, 0),
#  (779, 'alppiruusu', 0, 1, 0, 0, 0),
#  (780, 'alppitähti', 0, 1, 0, 0, 0),
#  (781, 'alsikeapila', 0, 1, 0, 0, 0),
#  (782, 'altavastaaja', 0, 1, 0, 0, 0),
#  (783, 'altis', 0, 0, 1, 0, 0),
#  (784, 'altistaa', 1, 0, 0, 0, 0),
#  (785, 'altistua', 1, 0, 0, 0, 0),
#  (786, 'altistus', 0, 1, 0, 0, 0),
#  (787, 'altruismi', 0, 1, 0, 0, 0),
#  (788, 'alttari', 0, 1, 0, 0, 0),
#  (789, 'alttariliina', 0, 1, 0, 0, 0),
#  (790, 'alttaritaulu', 0, 1, 0, 0, 0),
#  (791, 'alttius', 0, 1, 0, 0, 0),
#  (792, 'altto', 0, 1, 0, 0, 0),
#  (793, 'alttoviulu', 0, 1, 0, 0, 0),
#  (794, 'alttoääni', 0, 1, 0, 0, 0),
#  (795, 'alue', 0, 1, 0, 0, 0),
#  (796, 'alueellinen', 0, 0, 1, 0, 0),
#  (797, 'aluehallinto', 0, 1, 0, 0, 0),
#  (798, 'alueittainen', 0, 0, 1, 0, 0),
#  (799, 'aluemeri', 0, 1, 0, 0, 0),
#  (800, 'alueradio', 0, 1, 0, 0, 0),
#  (801, 'aluevaltaus', 0, 1, 0, 0, 0),
#  (802, 'aluevesi', 0, 1, 0, 0, 0),
#  (803, 'aluke', 0, 1, 0, 0, 0),
#  (804, 'alullepanija', 0, 1, 0, 0, 0),
#  (805, 'alumiini', 0, 1, 0, 0, 0),
#  (806, 'alumiinifolio', 0, 1, 0, 0, 0),
#  (807, 'alumiininen', 0, 0, 1, 0, 0),
#  (808, 'alumiinivene', 0, 1, 0, 0, 0),
#  (809, 'aluminointi', 0, 1, 0, 0, 0),
#  (810, 'aluna', 0, 1, 0, 0, 0),
#  (811, 'alus', 0, 1, 0, 0, 0),
#  (812, 'alusastia', 0, 1, 0, 0, 0),
#  (813, 'alushousut', 0, 1, 0, 0, 0),
#  (814, 'aluslautanen', 0, 1, 0, 0, 0),
#  (815, 'alusmaa', 0, 1, 0, 0, 0),
#  (816, 'aluspaita', 0, 1, 0, 0, 0),
#  (817, 'alusta', 0, 1, 0, 0, 0),
#  (818, 'alustaa', 1, 0, 0, 0, 0),
#  (819, 'alustaja', 0, 1, 0, 0, 0),
#  (820, 'alustalainen', 0, 1, 0, 0, 0),
#  (821, 'alustava', 0, 0, 0, 0, 0),
#  (822, 'alustus', 0, 1, 0, 0, 0),
#  (823, 'alusvaate', 0, 1, 0, 0, 0),
#  (824, 'alusvoide', 0, 1, 0, 0, 0),
#  (825, 'alvejuuri', 0, 1, 0, 0, 0),
#  (826, 'amalgaami', 0, 1, 0, 0, 0),
#  (827, 'amanuenssi', 0, 1, 0, 0, 0),
#  (828, 'amaryllis', 0, 1, 0, 0, 0),
#  (829, 'amatsoni', 0, 1, 0, 0, 0),
#  (830, 'amatööriys', 0, 1, 0, 0, 0),
#  (831, 'ambitio', 0, 1, 0, 0, 0),
#  (832, 'ambivalenssi', 0, 1, 0, 0, 0),
#  (833, 'ambra', 0, 1, 0, 0, 0),
#  (834, 'ambrosia', 0, 1, 0, 0, 0),
#  (835, 'ambulanssi', 0, 1, 0, 0, 0),
#  (836, 'ameba', 0, 1, 0, 0, 0),
#  (837, 'amerikanrauta', 0, 1, 0, 0, 0),
#  (838, 'amerikansuomi', 0, 1, 0, 0, 0),
#  (839, 'ametisti', 0, 1, 0, 0, 0),
#  (840, 'amfetamiini', 0, 1, 0, 0, 0),
#  (841, 'amfiteatteri', 0, 1, 0, 0, 0),
#  (842, 'amfora', 0, 1, 0, 0, 0),
#  (843, 'aminohappo', 0, 1, 0, 0, 0),
#  (844, 'amiraali', 0, 1, 0, 0, 0),
#  (845, 'ammatillinen', 0, 1, 0, 0, 0),
#  (846, 'ammatillisuus', 0, 1, 0, 0, 0),
#  (847, 'ammatti', 0, 1, 0, 0, 0),
#  (848, 'ammattikateus', 0, 1, 0, 0, 0),
#  (849, 'ammattikieli', 0, 1, 0, 0, 0),
#  (850, 'ammattikoulu', 0, 1, 0, 0, 0),
#  (851, 'ammattilainen', 0, 1, 0, 0, 0),
#  (852, 'ammattiliitto', 0, 1, 0, 0, 0),
#  (853, 'ammattimainen', 0, 0, 1, 0, 0),
#  (854, 'ammattimies', 0, 1, 0, 0, 0),
#  (855, 'ammattinimike', 0, 1, 0, 0, 0),
#  (856, 'ammattiosasto', 0, 1, 0, 0, 0),
#  (857, 'ammattislangi', 0, 1, 0, 0, 0),
#  (858, 'ammattitauti', 0, 1, 0, 0, 0),
#  (859, 'ammattiylpeys', 0, 1, 0, 0, 0),
#  (860, 'amme', 0, 1, 0, 0, 0),
#  (861, 'ammentaa', 1, 0, 0, 0, 0),
#  (862, 'ammoinen', 0, 0, 1, 0, 0),
#  (863, 'ammoniakki', 0, 1, 0, 0, 0),
#  (864, 'ammu', 0, 1, 0, 0, 0),
#  (865, 'ammua', 1, 0, 0, 0, 0),
#  (866, 'ammunta', 0, 1, 0, 0, 0),
#  (867, 'ammus', 0, 1, 0, 0, 0),
#  (868, 'ammuskelija', 0, 1, 0, 0, 0),
#  (869, 'ammuskella', 1, 0, 0, 0, 0),
#  (870, 'ammuskelu', 0, 1, 0, 0, 0),
#  (871, 'ammusvarasto', 0, 1, 0, 0, 0),
#  (872, 'ammuttaa', 1, 0, 0, 0, 0),
#  (873, 'amnesia', 0, 1, 0, 0, 0),
#  (874, 'amnestia', 0, 1, 0, 0, 0),
#  (875, 'amokjuoksu', 0, 1, 0, 0, 0),
#  (876, 'amorfinen', 0, 0, 1, 0, 0),
#  (877, 'amorfisuus', 0, 1, 0, 0, 0),
#  (878, 'amorinkaari', 0, 1, 0, 0, 0),
#  (879, 'ampeeri', 0, 1, 0, 0, 0),
#  (880, 'ampiainen', 0, 1, 0, 0, 0),
#  (881, 'amplitudi', 0, 1, 0, 0, 0),
#  (882, 'amppeli', 0, 1, 0, 0, 0),
#  (883, 'ampu', 0, 1, 0, 0, 0),
#  (884, 'ampua', 1, 0, 0, 0, 0),
#  (885, 'ampuhaukka', 0, 1, 0, 0, 0),
#  (886, 'ampuilla', 1, 0, 0, 0, 0),
#  (887, 'ampuja', 0, 1, 0, 0, 0),
#  (888, 'ampulli', 0, 1, 0, 0, 0),
#  (889, 'ampuma-ase', 0, 1, 0, 0, 0),
#  (890, 'ampuma-aukko', 0, 1, 0, 0, 0),
#  (891, 'ampumahiihto', 0, 1, 0, 0, 0),
#  (892, 'ampumarata', 0, 1, 0, 0, 0),
#  (893, 'ampumaurheilu', 0, 1, 0, 0, 0),
#  (894, 'amputaatio', 0, 1, 0, 0, 0),
#  (895, 'amputoida', 1, 0, 0, 0, 0),
#  (896, 'amputointi', 0, 1, 0, 0, 0),
#  (897, 'amuletti', 0, 1, 0, 0, 0),
#  (898, 'anaalinen', 0, 0, 1, 0, 0),
#  (899, 'anabolinen', 0, 0, 1, 0, 0),
#  (900, 'anaerobinen', 0, 0, 1, 0, 0),
#  (901, 'anagrammi', 0, 1, 0, 0, 0),
#  (902, 'anakonda', 0, 1, 0, 0, 0),
#  (903, 'anakronismi', 0, 1, 0, 0, 0),
#  (904, 'analfabeetti', 0, 1, 0, 0, 0),
#  (905, 'analgeettinen', 0, 0, 1, 0, 0),
#  (906, 'analogia', 0, 1, 0, 0, 0),
#  (907, 'analoginen', 0, 0, 1, 0, 0),
#  (908, 'analogisuus', 0, 1, 0, 0, 0),
#  (909, 'analysaattori', 0, 1, 0, 0, 0),
#  (910, 'analysoida', 1, 0, 0, 0, 0),
#  (911, 'analysointi', 0, 1, 0, 0, 0),
#  (912, 'analyysi', 0, 1, 0, 0, 0),
#  (913, 'analyytikko', 0, 1, 0, 0, 0),
#  (914, 'analyyttinen', 0, 0, 1, 0, 0),
#  (915, 'analyyttisuus', 0, 1, 0, 0, 0),
#  (916, 'analyyttisyys', 0, 1, 0, 0, 0),
#  (917, 'anamneesi', 0, 1, 0, 0, 0),
#  (918, 'ananas', 0, 1, 0, 0, 0),
#  (919, 'ananaskasvi', 0, 1, 0, 0, 0),
#  (920, 'ananasrengas', 0, 1, 0, 0, 0),
#  (921, 'anarkia', 0, 1, 0, 0, 0),
#  (922, 'anarkismi', 0, 1, 0, 0, 0),
#  (923, 'anarkisti', 0, 1, 0, 0, 0),
#  (924, 'anarkistinen', 0, 0, 1, 0, 0),
#  (925, 'anarkistisuus', 0, 1, 0, 0, 0),
#  (926, 'anastaa', 1, 0, 0, 0, 0),
#  (927, 'anastaja', 0, 1, 0, 0, 0),
#  (928, 'anastus', 0, 1, 0, 0, 0),
#  (929, 'anatomi', 0, 1, 0, 0, 0),
#  (930, 'anatomia', 0, 1, 0, 0, 0),
#  (931, 'anatominen', 0, 0, 1, 0, 0),
#  (932, 'andante', 0, 1, 0, 0, 0),
#  (933, 'androgeeni', 0, 1, 0, 0, 0),
#  (934, 'androgyyni', 0, 1, 0, 0, 0),
#  (935, 'androgyyninen', 0, 0, 1, 0, 0),
#  (936, 'andrologia', 0, 1, 0, 0, 0),
#  (937, 'ane', 0, 1, 0, 0, 0),
#  (938, 'aneeminen', 0, 0, 1, 0, 0),
#  (939, 'aneemisuus', 0, 1, 0, 0, 0),
#  (940, 'anekauppa', 0, 1, 0, 0, 0),
#  (941, 'anekdootti', 0, 1, 0, 0, 0),
#  (942, 'anella', 1, 0, 0, 0, 0),
#  (943, 'anemia', 0, 1, 0, 0, 0),
#  (944, 'anesteetti', 0, 1, 0, 0, 0),
#  (945, 'anestesia', 0, 1, 0, 0, 0),
#  (946, 'anestesiologi', 0, 1, 0, 0, 0),
#  (947, 'aneurysma', 0, 1, 0, 0, 0),
#  (948, 'angervo', 0, 1, 0, 0, 0),
#  (949, 'angiina', 0, 1, 0, 0, 0),
#  (950, 'angiografia', 0, 1, 0, 0, 0),
#  (951, 'anglikaaninen', 0, 0, 1, 0, 0),
#  (952, 'anglismi', 0, 1, 0, 0, 0),
#  (953, 'anglosaksi', 0, 1, 0, 0, 0),
#  (954, 'anglosaksinen', 0, 0, 1, 0, 0),
#  (955, 'angora', 0, 1, 0, 0, 0),
#  (956, 'angoravilla', 0, 1, 0, 0, 0),
#  (957, 'aniliini', 0, 1, 0, 0, 0),
#  (958, 'animaalisuus', 0, 1, 0, 0, 0),
#  (959, 'animaatio', 0, 1, 0, 0, 0),
#  (960, 'animismi', 0, 1, 0, 0, 0),
#  (961, 'animistinen', 0, 0, 1, 0, 0),
#  (962, 'anioni', 0, 1, 0, 0, 0),
#  (963, 'anis', 0, 1, 0, 0, 0),
#  (964, 'anislikööri', 0, 1, 0, 0, 0),
#  (965, 'anjovis', 0, 1, 0, 0, 0),
#  (966, 'ankara', 0, 0, 1, 0, 0),
#  (967, 'ankaruus', 0, 1, 0, 0, 0),
#  (968, 'ankea', 0, 0, 1, 0, 0),
#  (969, 'ankerias', 0, 1, 0, 0, 0),
#  (970, 'ankeus', 0, 1, 0, 0, 0),
#  (971, 'ankka', 0, 1, 0, 0, 0),
#  (972, 'ankkalammikko', 0, 1, 0, 0, 0),
#  (973, 'ankkuri', 0, 1, 0, 0, 0),
#  (974, 'ankkurihissi', 0, 1, 0, 0, 0),
#  (975, 'ankkuriköysi', 0, 1, 0, 0, 0),
#  (976, 'ankkuripaikka', 0, 1, 0, 0, 0),
#  (977, 'ankkuroida', 1, 0, 0, 0, 0),
#  (978, 'ankkurointi', 0, 1, 0, 0, 0),
#  (979, 'annansilmä', 0, 1, 0, 0, 0),
#  (980, 'annella', 1, 0, 0, 0, 0),
#  (981, 'anniskella', 1, 0, 0, 0, 0),
#  (982, 'anniskelu', 0, 1, 0, 0, 0),
#  (983, 'annoona', 0, 1, 0, 0, 0),
#  (984, 'annos', 0, 1, 0, 0, 0),
#  (985, 'annosmittari', 0, 1, 0, 0, 0),
#  (986, 'annostelu', 0, 1, 0, 0, 0),
#  (987, 'annostus', 0, 1, 0, 0, 0),
#  (988, 'anoa', 1, 0, 0, 0, 0),
#  (989, 'anodi', 0, 1, 0, 0, 0),
#  (990, 'anoja', 0, 1, 0, 0, 0),
#  (991, 'anomaalisuus', 0, 1, 0, 0, 0),
#  (992, 'anomalia', 0, 1, 0, 0, 0),
#  (993, 'anomus', 0, 1, 0, 0, 0),
#  (994, 'anonymiteetti', 0, 1, 0, 0, 0),
#  (995, 'anonyymi', 0, 1, 1, 0, 0),
#  (996, 'anonyymius', 0, 1, 0, 0, 0),
#  (997, 'anonyymiys', 0, 1, 0, 0, 0),
#  (998, 'anopinkieli', 0, 1, 0, 0, 0),
#  (999, 'anoppi', 0, 1, 0, 0, 0),
#  ...]
